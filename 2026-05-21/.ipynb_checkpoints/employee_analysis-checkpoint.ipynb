# %%
import pandas as pd

# %%
df = pd.read_csv(r"companyDB.Employee.csv")

# %%
df
# Out:
#                         _id  id                      name          username  \
# 0  6a0ec98de428dd7bfbfcf9e7   6      Mrs. Dennis Schulist  Leopoldo_Corkery
# 1  6a0ec98de428dd7bfbfcf9e8   1             Leanne Graham              Bret
# 2  6a0ec98de428dd7bfbfcf9e9   5          Chelsey Dietrich            Kamren
# 3  6a0ec98de428dd7bfbfcf9ea   9           Glenna Reichert          Delphine
# 4  6a0ec98de428dd7bfbfcf9eb  10        Clementina DuBuque    Moriah.Stanton
# 5  6a0ec98de428dd7bfbfcf9ec   4          Patricia Lebsack          Karianne
# 6  6a0ec98de428dd7bfbfcf9ed   2              Ervin Howell         Antonette
# 7  6a0ec98de428dd7bfbfcf9ee   3          Clementine Bauch          Samantha
# 8  6a0ec98de428dd7bfbfcf9ef   7           Kurtis Weissnat      Elwyn.Skiles
# 9  6a0ec98de428dd7bfbfcf9f0   8  Nicholas Runolfsdottir V     Maxime_Nienow
#
#                        email     address.street address.suite    address.city  \
# ...

# %%
df.head()
# Out:
#                         _id  id                  name          username  \
# 0  6a0ec98de428dd7bfbfcf9e7   6  Mrs. Dennis Schulist  Leopoldo_Corkery
# 1  6a0ec98de428dd7bfbfcf9e8   1         Leanne Graham              Bret
# 2  6a0ec98de428dd7bfbfcf9e9   5      Chelsey Dietrich            Kamren
# 3  6a0ec98de428dd7bfbfcf9ea   9       Glenna Reichert          Delphine
# 4  6a0ec98de428dd7bfbfcf9eb  10    Clementina DuBuque    Moriah.Stanton
#
#                       email     address.street address.suite    address.city  \
# 0   Karley_Dach@jasper.info  Norberto Crossing      Apt. 950   South Christy
# 1         Sincere@april.biz        Kulas Light      Apt. 556     Gwenborough
# 2  Lucio_Hettinger@annie.ca       Skiles Walks     Suite 351      Roscoeview
# 3   Chaim_McDermott@dana.io         Dayna Park     Suite 449  Bartholomebury
# 4    Rey.Padberg@karina.biz    Kattie Turnpike     Suite 198     Lebsackbury
#
# ...

# %%
df.tail()
# Out:
#                         _id  id                      name       username  \
# 5  6a0ec98de428dd7bfbfcf9ec   4          Patricia Lebsack       Karianne
# 6  6a0ec98de428dd7bfbfcf9ed   2              Ervin Howell      Antonette
# 7  6a0ec98de428dd7bfbfcf9ee   3          Clementine Bauch       Samantha
# 8  6a0ec98de428dd7bfbfcf9ef   7           Kurtis Weissnat   Elwyn.Skiles
# 9  6a0ec98de428dd7bfbfcf9f0   8  Nicholas Runolfsdottir V  Maxime_Nienow
#
#                        email     address.street address.suite   address.city  \
# 5  Julianne.OConner@kory.org        Hoeger Mall      Apt. 692    South Elvis
# 6          Shanna@melissa.tv      Victor Plains     Suite 879    Wisokyburgh
# 7         Nathan@yesenia.net  Douglas Extension     Suite 847  McKenziehaven
# 8     Telly.Hoeger@billy.biz          Rex Trail     Suite 280      Howemouth
# 9       Sherwood@rosamond.me   Ellsworth Summit     Suite 729      Aliyaview
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  10 non-null     object
#  1   id                   10 non-null     int64
#  2   name                 10 non-null     object
#  3   username             10 non-null     object
#  4   email                10 non-null     object
#  5   address.street       10 non-null     object
#  6   address.suite        10 non-null     object
#  7   address.city         10 non-null     object
#  8   address.zipcode      10 non-null     object
#  9   address.geo.lat      10 non-null     float64
#  10  address.geo.lng      10 non-null     float64
#  11  phone                10 non-null     object
#  12  website              10 non-null     object
#  13  company.name         10 non-null     object
#  14  company.catchPhrase  10 non-null     object
# ...

# %%
df.describe()
# Out:
#              id  address.geo.lat  address.geo.lng
# count  10.00000        10.000000        10.000000
# mean    5.50000       -22.675190       -24.092950
# std     3.02765        37.663716        98.374613
# min     1.00000       -71.419700      -168.888900
# 25%     3.25000       -42.522825      -102.342100
# 50%     5.50000       -34.564400        -6.281700
# 75%     7.75000        14.884975        61.206450
# max    10.00000        29.457200        81.149600

# %%
df.dtypes
# Out:
# _id                     object
# id                       int64
# name                    object
# username                object
# email                   object
# address.street          object
# address.suite           object
# address.city            object
# address.zipcode         object
# address.geo.lat        float64
# address.geo.lng        float64
# phone                   object
# website                 object
# company.name            object
# company.catchPhrase     object
# company.bs              object
# dtype: object

# %%
df["name"].unique()
# Out:
# array(['Mrs. Dennis Schulist', 'Leanne Graham', 'Chelsey Dietrich',
#        'Glenna Reichert', 'Clementina DuBuque', 'Patricia Lebsack',
#        'Ervin Howell', 'Clementine Bauch', 'Kurtis Weissnat',
#        'Nicholas Runolfsdottir V'], dtype=object)

# %%
df.isnull()
# Out:
#      _id     id   name  username  email  address.street  address.suite  \
# 0  False  False  False     False  False           False          False
# 1  False  False  False     False  False           False          False
# 2  False  False  False     False  False           False          False
# 3  False  False  False     False  False           False          False
# 4  False  False  False     False  False           False          False
# 5  False  False  False     False  False           False          False
# 6  False  False  False     False  False           False          False
# 7  False  False  False     False  False           False          False
# 8  False  False  False     False  False           False          False
# 9  False  False  False     False  False           False          False
#
#    address.city  address.zipcode  address.geo.lat  address.geo.lng  phone  \
# 0         False            False            False            False  False
# ...

# %%
df.isnull().sum()
# Out:
# _id                    0
# id                     0
# name                   0
# username               0
# email                  0
# address.street         0
# address.suite          0
# address.city           0
# address.zipcode        0
# address.geo.lat        0
# address.geo.lng        0
# phone                  0
# website                0
# company.name           0
# company.catchPhrase    0
# company.bs             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv("employee_analysis.csv",index=False)

# %%
df.to_xml("employee_analysis.xml", index=False)

# %%
df
# Out:
#                         _id  id                      name          username  \
# 0  6a0ec98de428dd7bfbfcf9e7   6      Mrs. Dennis Schulist  Leopoldo_Corkery
# 1  6a0ec98de428dd7bfbfcf9e8   1             Leanne Graham              Bret
# 2  6a0ec98de428dd7bfbfcf9e9   5          Chelsey Dietrich            Kamren
# 3  6a0ec98de428dd7bfbfcf9ea   9           Glenna Reichert          Delphine
# 4  6a0ec98de428dd7bfbfcf9eb  10        Clementina DuBuque    Moriah.Stanton
# 5  6a0ec98de428dd7bfbfcf9ec   4          Patricia Lebsack          Karianne
# 6  6a0ec98de428dd7bfbfcf9ed   2              Ervin Howell         Antonette
# 7  6a0ec98de428dd7bfbfcf9ee   3          Clementine Bauch          Samantha
# 8  6a0ec98de428dd7bfbfcf9ef   7           Kurtis Weissnat      Elwyn.Skiles
# 9  6a0ec98de428dd7bfbfcf9f0   8  Nicholas Runolfsdottir V     Maxime_Nienow
#
#                        email     address.street address.suite    address.city  \
# ...
