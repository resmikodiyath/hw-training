# %%
import pandas as pd

# %%
df=pd.read_csv(r"/home/resmi/Downloads/DataHut_AT_Dm_PriceExtractions_20260616.CSV",sep="|")

# %%
df.to_parquet(r"/home/resmi/Downloads/DataHut_AT_Dm_PriceExtractions_20260616.parquet", engine='pyarrow', index=False)

# %%
df=pd.read_parquet(r"/home/resmi/Downloads/DataHut_AT_Dm_PriceExtractions_20260616.parquet", engine='pyarrow')

# %%
df
# Out:
#            unique_id competitor_name extraction_date  \
# 0      4059729626592              dm      2026-06-16
# 1      2090000510157              dm      2026-06-16
# 2      4059729626431              dm      2026-06-16
# 3       800897280741              dm      2026-06-16
# 4       800897281526              dm      2026-06-16
# ...              ...             ...             ...
# 16677       30118874              dm      2026-06-16
# 16678       30101678              dm      2026-06-16
# 16679       30108356              dm      2026-06-16
# 16680       30121416              dm      2026-06-16
# 16681       30098787              dm      2026-06-16
#
#                                             product_name grammage_quantity  \
# 0      Körperspray Juicy Bomb Tropical Drop 110 Mango...               100
# 1                  Jubiläumsbox 50 Jahre dm Beauty, 1 St                 1
# 2      Körperspray Juicy Bomb Tropical Drop 106 Lyche...               100
# ...

# %%
df.to_csv(r"/home/resmi/Downloads/DataHut_AT_Dm_PriceExtractions_20260616.csv", index=False)

# %%
df = pd.read_csv((r"/home/resmi/Downloads/DataHut_AT_Dm_PriceExtractions_20260616.CSV"), sep="|")

# %%
df
# Out:
#            unique_id competitor_name extraction_date  \
# 0      4059729626592              dm      2026-06-16
# 1      2090000510157              dm      2026-06-16
# 2      4059729626431              dm      2026-06-16
# 3       800897280741              dm      2026-06-16
# 4       800897281526              dm      2026-06-16
# ...              ...             ...             ...
# 16677       30118874              dm      2026-06-16
# 16678       30101678              dm      2026-06-16
# 16679       30108356              dm      2026-06-16
# 16680       30121416              dm      2026-06-16
# 16681       30098787              dm      2026-06-16
#
#                                             product_name grammage_quantity  \
# 0      Körperspray Juicy Bomb Tropical Drop 110 Mango...               100
# 1                  Jubiläumsbox 50 Jahre dm Beauty, 1 St                 1
# 2      Körperspray Juicy Bomb Tropical Drop 106 Lyche...               100
# ...
