# %%
import pandas as pd

# %%
pd.read_json(r"/home/resmi/Downloads/sutton_2026_06_05 (1).json", lines=True).to_parquet(r"/home/resmi/Downloads/sutton_2026_06_05 (1).parquet", engine='pyarrow', index=False)

# %%
df=pd.read_parquet((r"/home/resmi/Downloads/sutton_2026_06_05 (1).parquet"), engine='pyarrow')

# %%
df
# Out:
#        first_name middle_name        last_name  \
# 0     Yenisleidis              Infante Morales
# 1          Ingrid                         Keen
# 2           Linda                        D'Eon
# 3         Youngho                          Kim
# 4           Brian                        Power
# ...           ...         ...              ...
# 5040      Mathieu                   Aubry inc.
# 5041        Susan                     Borinsky
# 5042        Lacey                     Westcott
# 5043         Cody                     Robinson
# 5044         Gary                     Dhanesar
#
#                                            office_name  \
# 0                          groupe sutton - clodem inc.
# 1         Sutton Group - Summit Realty Inc., Brokerage
# 2        Sutton Group - Quantum Realty Inc., Brokerage
# 3                     Sutton Group - West Coast Realty
# 4                     Sutton Group - West Coast Realty
# ...                                                ...
# ...

# %%
df.to_json(r"/home/resmi/Downloads/sutton_2026_06_05 (1).json", orient='records', lines=True, index=False)

# %%
pd.read_json(r"/home/resmi/Downloads/sutton_2026_06_05 (1).json", lines=True)
# Out:
#        first_name middle_name        last_name  \
# 0     Yenisleidis              Infante Morales
# 1          Ingrid                         Keen
# 2           Linda                        D'Eon
# 3         Youngho                          Kim
# 4           Brian                        Power
# ...           ...         ...              ...
# 5040      Mathieu                   Aubry inc.
# 5041        Susan                     Borinsky
# 5042        Lacey                     Westcott
# 5043         Cody                     Robinson
# 5044         Gary                     Dhanesar
#
#                                            office_name  \
# 0                          groupe sutton - clodem inc.
# 1         Sutton Group - Summit Realty Inc., Brokerage
# 2        Sutton Group - Quantum Realty Inc., Brokerage
# 3                     Sutton Group - West Coast Realty
# 4                     Sutton Group - West Coast Realty
# ...                                                ...
# ...

# %%
df.to_excel(r"/home/resmi/Downloads/sutton_2026_06_05 (1).xlsx", index=False)

# %%
df.to_parquet(r"/home/resmi/Downloads/sutton_2026_06_05 (1).parquet", engine='pyarrow', index=False)
